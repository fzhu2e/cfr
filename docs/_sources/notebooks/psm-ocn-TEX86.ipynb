# %%
# %load_ext autoreload
# %autoreload 2

import cfr
print(cfr.__version__)
import numpy as np
import os
# Out:
# 2024.1.26

# %%
import bayspar as bsr

sst = np.arange(0, 41)
prediction = bsr.predict_tex(sst, lon=34.0733, lat=31.6517, temptype='sst')

ax = bsr.predictplot(prediction, x=sst, xlabel='SST (°C)', ylabel=r'TEX$_{86}$')

# %%
print(prediction.percentile()[:, 1])
# Out:
# [0.2692508  0.28437885 0.29893764 0.3170121  0.3309044  0.34721148
#  0.36371272 0.37706489 0.39648115 0.41018133 0.42505943 0.44242118
#  0.45852373 0.47390029 0.48921162 0.50320318 0.51911414 0.53492034
#  0.55187766 0.56663146 0.58309529 0.59724898 0.61576552 0.62866408
#  0.64550433 0.66072121 0.6767111  0.69433802 0.70737955 0.72440517
#  0.73982124 0.755043   0.77102635 0.78659133 0.8032723  0.81710502
#  0.83408906 0.84912732 0.86433709 0.88054535 0.89587475]
# /glade/derecho/scratch/fengzhu/tmp/ipykernel_62881/2164839693.py:1: DeprecationWarning: the `interpolation=` argument to percentile was renamed to `method=`, which has additional options.
# Users of the modes 'nearest', 'lower', 'higher', or 'midpoint' are encouraged to review the method they used. (Deprecated NumPy 1.22)
#   print(prediction.percentile()[:, 1])
