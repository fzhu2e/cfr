# %%
# %load_ext autoreload
# %autoreload 2

import cfr
import pandas as pd
import LMRt

# %%
job = cfr.ReconJob(verbose=True)
job.load_proxydb('./data/pages2k_updated_Palmyra_dataset.pkl', verbose=True)
# Out:
# >>> job.configs:
# {}
# >>> job.configs["proxydb_path"] = ./data/pages2k_updated_Palmyra_dataset.pkl
# >>> 692 records loaded
# >>> job.proxydb created

# %%
pids = [
    'Ocn_065',
    'Ocn_075',
    'Ocn_096',
    'Ocn_101',
    'Ocn_070',
    'Ocn_103',
    'Ocn_077',
    'Ocn_122',
    'Ocn_095',
    'Ocn_104',
    'Ocn_125',
    'Ocn_087',
]

job.filter_proxydb(by='pid', keys=pids)

# pobj = job.proxydb.records['Ocn_075']
pobj = job.proxydb.records['Ocn_103']
pobj.time
# Out:
# array([ 928.125,  928.209,  928.292, ..., 1998.21 , 1998.294, 1998.377])

# %%
import xarray as xr

dates = cfr.utils.year_float2datetime(pobj.time)
da_wk = xr.DataArray(
    pobj.value, dims=['time'], coords={'time': dates}
)
da_wk
# Out:
# <xarray.DataArray (time: 6384)>
# array([-4.651, -4.631, -4.629, ..., -5.469, -5.413, -5.262])
# Coordinates:
#   * time     (time) object 0928-02-01 00:00:00 ... 1998-05-01 00:00:00

# %%
months = [12, 1, 2]
sda = da_wk.sel(time=da_wk.time.dt.month.isin([months]))
sda
# Out:
# <xarray.DataArray (time: 1596)>
# array([-4.651, -4.546, -4.471, ..., -5.48 , -5.435, -5.493])
# Coordinates:
#   * time     (time) object 0928-02-01 00:00:00 ... 1998-02-01 00:00:00

# %%
anchor = ['JAN', 'FEB', 'MAR', 'APR', 'MAY', 'JUN', 'JUL', 'AUG', 'SEP', 'OCT', 'NOV', 'DEC']
idx = months[-1]-1
print(anchor[idx])
sda_ann = sda.resample(time=f'A-{anchor[idx]}').mean()
sda_ann
# Out:
# FEB
# <xarray.DataArray (time: 1071)>
# array([-4.651     , -4.48166667, -4.54933333, ..., -5.009     ,
#        -5.20033333, -5.46933333])
# Coordinates:
#   * time     (time) object 0928-02-29 00:00:00 ... 1998-02-28 00:00:00

# %%
import numpy as np
time_ann = np.floor(cfr.utils.datetime2year_float(sda_ann.time.values))
print(time_ann)
print(len(time_ann))
# Out:
# [ 928.  929.  930. ... 1996. 1997. 1998.]
# 1071

# %%
job.annualize_proxydb(months=[12, 1, 2], ptypes=['coral'], verbose=True)
# Out:
# >>> job.configs["annualize_proxydb_months"] = [12, 1, 2]
# >>> job.configs["annualize_proxydb_ptypes"] = ['coral']
# Annualizing ProxyRecord: 100%|██████████| 12/12 [00:00<00:00, 28.34it/s]
# >>> 12 records remaining
# >>> job.proxydb updated

# %%
import numpy as np

job_old = pd.read_pickle('./data/job.pkl')
for pid, pobj in job.proxydb.records.items():
    pobj_old = job_old.proxydb.records[pid]
    try:
        print(
            pobj.time[0], pobj_old.time[0],
            pobj.time[-1], pobj_old.time[-1],
        )
        print(np.sum(pobj.value - pobj_old.value))
# -4.722333333333333 -4.668
# -4.691666666666666 -4.712666666666667
# -4.857333333333333 -4.805
# -4.843 -4.845666666666667
# -4.671666666666667 -4.739333333333334
# -4.945333333333333 -4.852
# -4.681666666666667 -4.781666666666667
# -4.582 -4.588
# -4.914333333333334 -4.818333333333333
# -4.97 -4.9526666666666666
# -4.713 -4.789666666666666
# -4.842333333333333 -4.815
# -4.800000000000001 -4.8
# -4.777333333333334 -4.771999999999999
# -4.751 -4.746666666666667
# -4.682 -4.707
# -4.875 -4.841666666666666
# -4.838666666666667 -4.847333333333333
# -4.682666666666667 -4.715
# -4.689 -4.722
# -4.7219999999999995 -4.674666666666667
# -4.8373333333333335 -4.815333333333334
# -4.820333333333333 -4.820333333333333
# -4.739333333333334 -4.758666666666667
# -4.854333333333334 -4.834
# -4.7540000000000004 -4.802666666666667
# -4.809 -4.7746666666666675
# -4.7540000000000004 -4.77
# -4.729 -4.727666666666667
# -4.737666666666667 -4.7523333333333335
# -4.698999999999999 -4.697333333333334
# -4.715000000000001 -4.710333333333334
# -4.845 -4.823
# -4.8133333333333335 -4.812
# -4.915 -4.882000000000001
# -4.881333333333333 -4.880999999999999
# -4.751666666666667 -4.793
# -4.759 -4.785333333333334
# -4.611666666666667 -4.6513333333333335
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /Users/fzhu/Github/cfr/docsrc/notebooks/check_corals.ipynb Cell 10' in <cell line: 5>()
#       <a href='vscode-notebook-cell:/Users/fzhu/Github/cfr/docsrc/notebooks/check_corals.ipynb#ch0000010?line=2'>3</a> pobj = job.proxydb.records[pid]
#       <a href='vscode-notebook-cell:/Users/fzhu/Github/cfr/docsrc/notebooks/check_corals.ipynb#ch0000010?line=4'>5</a> for t in pobj.time:
# ----> <a href='vscode-notebook-cell:/Users/fzhu/Github/cfr/docsrc/notebooks/check_corals.ipynb#ch0000010?line=5'>6</a>     idx_old = list(pobj_old.time).index(t)
#       <a href='vscode-notebook-cell:/Users/fzhu/Github/cfr/docsrc/notebooks/check_corals.ipynb#ch0000010?line=6'>7</a>     idx = list(pobj.time).index(t)
#       <a href='vscode-notebook-cell:/Users/fzhu/Github/cfr/docsrc/notebooks/check_corals.ipynb#ch0000010?line=7'>8</a>     print(pobj_old.value[idx_old], pobj.value[idx])
#
# ValueError: 1464.0 is not in list

# %%
pid = 'Ocn_077'
pobj_old = job_old.proxydb.records[pid]
pobj = job.proxydb.records[pid]

for t in pobj.time:
    idx_old = list(pobj_old.time).index(t)
    idx = list(pobj.time).index(t)
    print(pobj_old.value[idx_old], pobj.value[idx])
# Out:
# -3.852 -4.055
# -4.145 -3.852
# -3.77 -4.145
# -3.975 -3.77
# -4.069 -3.975
# -4.045 -4.069
# -4.104 -4.045
# -3.977 -4.104
# -3.944 -3.977
# -3.926 -3.944
# -4.05 -3.926
# -4.015 -4.05
# -4.157 -4.015
# -3.983 -4.157
# -3.952 -3.983
# -4.208 -3.952
# -4.096 -4.208
# -4.049 -4.096
# -4.097 -4.049
# -4.189 -4.097
# -4.143 -4.189
# -4.088 -4.143
# -4.054 -4.088
# -4.079 -4.054
# -4.356 -4.079
# -3.995 -4.356
# -3.836 -3.995
# -4.218 -3.836
# -4.03 -4.218
# -4.049 -4.03
# -4.08 -4.049
# -4.103 -4.08
# -4.043 -4.103
# -4.178 -4.043
# -4.076 -4.178
# -4.221 -4.076
# -4.342 -4.221
# -4.325 -4.342
# -4.133 -4.325
# -4.124 -4.133
# -4.339 -4.124
# -4.236 -4.339
# -4.017 -4.236
# -4.275 -4.017
# -3.908 -4.275
# -4.039 -3.908
# -4.13 -4.039
# -3.923 -4.13
# -3.981 -3.923
# -4.009 -3.981
# -4.067 -4.009
# -3.967 -4.067
# -3.923 -3.967
# -3.804 -3.923
# -3.948 -3.804
# -4.175 -3.948
# -4.008 -4.175
# -4.118 -4.008
# -4.032 -4.118
# -4.271 -4.032
# -3.976 -4.271
# -4.079 -3.976
# -4.201 -4.079
# -3.818 -4.201
# -4.166 -3.818
# -4.212 -4.166
# -4.254 -4.212
# -4.034 -4.254
# -4.002 -4.034
# -4.108 -4.002
# -4.264 -4.108
# -4.149 -4.264
# -4.171 -4.149
# -4.159 -4.171
# -4.095 -4.159
# -4.143 -4.095
# -4.172 -4.143
# -4.024 -4.172
# -4.029 -4.024
# -3.94 -4.029
# -3.792 -3.94
# -4.167 -3.792
# -4.014 -4.167
# -4.015 -4.014
# -4.098 -4.015
# -3.846 -4.098
# -4.02 -3.846
# -3.923 -4.02
# -3.918 -3.923
# -3.976 -3.918
# -3.992 -3.976
# -4.114 -3.992
# -4.159 -4.114
# -4.099 -4.159
# -3.988 -4.099
# -4.035 -3.988
# -3.959 -4.035
# -3.978 -3.959
# -3.939 -3.978
# -4.057 -3.939
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /Users/fzhu/Github/cfr/docsrc/notebooks/check_corals.ipynb Cell 12' in <cell line: 5>()
#       <a href='vscode-notebook-cell:/Users/fzhu/Github/cfr/docsrc/notebooks/check_corals.ipynb#ch0000006?line=2'>3</a> pobj = job.proxydb.records[pid]
#       <a href='vscode-notebook-cell:/Users/fzhu/Github/cfr/docsrc/notebooks/check_corals.ipynb#ch0000006?line=4'>5</a> for t in pobj.time:
# ----> <a href='vscode-notebook-cell:/Users/fzhu/Github/cfr/docsrc/notebooks/check_corals.ipynb#ch0000006?line=5'>6</a>     idx_old = list(pobj_old.time).index(t)
#       <a href='vscode-notebook-cell:/Users/fzhu/Github/cfr/docsrc/notebooks/check_corals.ipynb#ch0000006?line=6'>7</a>     idx = list(pobj.time).index(t)
#       <a href='vscode-notebook-cell:/Users/fzhu/Github/cfr/docsrc/notebooks/check_corals.ipynb#ch0000006?line=7'>8</a>     print(pobj_old.value[idx_old], pobj.value[idx])
#
# ValueError: 1722.0 is not in list
