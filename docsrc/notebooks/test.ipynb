# %%
# %load_ext autoreload
# %autoreload 2

import os
import xarray as xr
import numpy as np
import cfr

# %%
job = cfr.ReconJob(verbose=True)
# Out:
# job.configs:
# {}

# %%
job.load_proxydb('./data/pages2k_dataset.pkl', verbose=True)
# Out:
# job.configs["proxydb_path"] = ./data/pages2k_dataset.pkl
# job.proxydb created with source: ./data/pages2k_dataset.pkl

# %%
fig, ax = job.proxydb.plot()
